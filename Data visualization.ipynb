# %%
import winsound as ws
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
ws.Beep(500, 500)

# %%
dataBooks = pd.read_csv("dataset\\books.csv")
dataBooks.head()
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1   2        3             3  4640799          491  439554934  9.780440e+12
# 2   3    41865         41865  3212258          226  316015849  9.780316e+12
# 3   4     2657          2657  3275794          487   61120081  9.780061e+12
# 4   5     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
# 3                   Harper Lee                     1960.0
# 4          F. Scott Fitzgerald                     1925.0
#
#                              original_title  \
# 0                          The Hunger Games
# 1  Harry Potter and the Philosopher's Stone
# ...

# %%
dataRatings = pd.read_csv("dataset\\ratings.csv")
dataRatings
# Out:
#         book_id  user_id  rating
# 0             1      314       5
# 1             1      439       3
# 2             1      588       5
# 3             1     1169       4
# 4             1     1185       4
# 5             1     2077       4
# 6             1     2487       4
# 7             1     2900       5
# 8             1     3662       4
# 9             1     3922       5
# 10            1     5379       5
# 11            1     5461       3
# 12            1     5885       5
# 13            1     6630       5
# 14            1     7563       3
# 15            1     9246       1
# 16            1    10140       4
# 17            1    10146       5
# 18            1    10246       4
# 19            1    10335       4
# 20            1    10610       5
# 21            1    10944       5
# 22            1    11854       4
# 23            1    11927       4
# 24            1    12471       5
# 25            1    13282       5
# 26            1    13544       5
# ...

# %%
dataTags = pd.read_csv("dataset\\tags.csv")
dataTags[90:110]
# Out:
#        tag_id                     tag_name
# 0           0                            -
# 1           1                         --1-
# 2           2                        --10-
# 3           3                        --12-
# 4           4                       --122-
# 5           5                       --166-
# 6           6                        --17-
# 7           7                        --19-
# 8           8                         --2-
# 9           9                       --258-
# 10         10                         --3-
# 11         11                        --33-
# 12         12                         --4-
# 13         13                         --5-
# 14         14                        --51-
# 15         15                         --6-
# 16         16                        --62-
# 17         17                         --8-
# 18         18                        --99-
# 19         19  --available-at-raspberrys--
# 20         20                      -2001--
# ...

# %%
dataToread = pd.read_csv("dataset\\to_read.csv")
dataToread.head()
# Out:
#    user_id  book_id
# 0        1      112
# 1        1      235
# 2        1      533
# 3        1     1198
# 4        1     1874

# %%
dataBooktag = pd.read_csv("dataset\\book_tags.csv")
dataBooktag
# Out:
#         goodreads_book_id  tag_id   count
# 0                       1   30574  167697
# 1                       1   11305   37174
# 2                       1   11557   34173
# 3                       1    8717   12986
# 4                       1   33114   12716
# 5                       1   11743    9954
# 6                       1   14017    7169
# 7                       1    5207    6221
# 8                       1   22743    4974
# 9                       1   32989    4364
# 10                      1   27199    3857
# 11                      1   11590    3456
# 12                      1   18886    3374
# 13                      1    6953    2408
# 14                      1   22753    1881
# 15                      1   24960    1821
# 16                      1    1691    1742
# 17                      1    6857    1560
# 18                      1   15965    1309
# 19                      1    6888    1095
# 20                      1   26785    1093
# ...

# %%
#filtro o così
df_filtered = dataBooktag.mask(lambda x: x['goodreads_book_id'] != 3)
df_filtered.dropna()
# Out:
#      goodreads_book_id   tag_id     count
# 200                3.0  30574.0  496107.0
# 201                3.0  11557.0   48220.0
# 202                3.0  11305.0   47478.0
# 203                3.0   8717.0   44640.0
# 204                3.0  33114.0   14984.0
# 205                3.0  11743.0   13239.0
# 206                3.0  14017.0    8559.0
# 207                3.0   5207.0    7917.0
# 208                3.0  22743.0    6066.0
# 209                3.0  22743.0    6065.0
# 210                3.0  32989.0    5276.0
# 211                3.0  27199.0    5140.0
# 212                3.0  11590.0    4769.0
# 213                3.0  18886.0    4302.0
# 214                3.0   6953.0    3828.0
# 215                3.0  24960.0    3163.0
# 216                3.0   6857.0    2571.0
# 217                3.0   1691.0    2430.0
# 218                3.0  22753.0    2350.0
# 219                3.0   7457.0    1898.0
# 220                3.0   6888.0    1771.0
# ...

# %%
dataBooks[(dataBooks.book_id == 3)]
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 1   2        3             3  4640799          491  439554934  9.780440e+12
#
#                        authors  original_publication_year  \
# 1  J.K. Rowling, Mary GrandPré                     1997.0
#
#                              original_title  \
# 1  Harry Potter and the Philosopher's Stone
#
#                          ...                         ratings_count  \
# 1                        ...                               4602479
#
#   work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 1            4800065                    75867      75504     101676
#
#    ratings_3  ratings_4  ratings_5  \
# 1     455024    1156318    3011543
#
#                                            image_url  \
# 1  https://images.gr-assets.com/books/1474154022m...
#
#                                      small_image_url
# 1  https://images.gr-assets.com/books/1474154022s...
#
# ...

# %%
dataTags.mask(lambda x : x["tag_id"] != 30574 ).dropna()
# Out:
#         tag_id tag_name
# 30574  30574.0  to-read

# %%
dataTags[(dataTags.tag_id == 11557) | (dataTags.tag_id == 30574) | (dataTags.tag_id == 11305) | (dataTags.tag_id == 8717)]
# Out:
#        tag_id           tag_name
# 8717     8717  currently-reading
# 11305   11305            fantasy
# 11557   11557          favorites
# 30574   30574            to-read

# %%
dataRatings[(dataRatings.user_id == 7)]
# Out:
#         book_id  user_id  rating
# 58397       585        7       4
# 90897       910        7       4
# 95497       956        7       5
# 106997     1071        7       4
# 119784     1199        7       4
# 146279     1464        7       5
# 148278     1484        7       5
# 151778     1519        7       5
# 153478     1536        7       4
# 161877     1620        7       5
# 164477     1646        7       3
# 179966     1801        7       5
# 187162     1873        7       4
# 191662     1918        7       3
# 192162     1923        7       4
# 196693     1969        7       5
# 198893     1991        7       4
# 204276     2045        7       3
# 208176     2084        7       5
# 209973     2102        7       4
# 212673     2129        7       5
# 218673     2189        7       3
# 223870     2241        7       2
# 232241     2325        7       4
# 246734     2470        7       3
# 248433     2487        7       5
# 248833     2491        7       1
# ...

# %%
dataBooks[(dataBooks.id == 585) | (dataBooks.id == 910) | (dataBooks.id == 9103) | (dataBooks.id == 8654)]
# Out:
#         id  book_id  best_book_id  work_id  books_count        isbn  \
# 584    585    13615         13615  1782155           44  1421501686
# 909    910    51964         51964    50700           64   765348276
# 8653  8654   587638        587638  2636942           36   345501748
# 9102  9103    15561         15561  2587875           51  1857231031
#
#             isbn13                      authors  original_publication_year  \
# 584   9.781422e+12  Tsugumi Ohba, Takeshi Obata                     2004.0
# 909   9.780765e+12                  John Scalzi                     2005.0
# 8653  9.780346e+12  Michael Chabon, Gary Gianni                     2007.0
# 9102  9.781857e+12                 Terry Brooks                     1987.0
#
#                           original_title  \
# 584   デスノート #1 (Desu Nōto) Taikutsu (退屈)
# 909                        Old Man's War
# 8653               Gentlemen of the Road
# 9102                    Wizard at Large
#
# ...
